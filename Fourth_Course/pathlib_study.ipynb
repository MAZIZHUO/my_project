# %%
print('hello')
# Out:
# hello

# %%
from pathlib import Path
path = Path("C:\\Users\\hp\\Desktop\\test.txt")
contents = path.read_text()
print(contents[0:5]) 
print(contents.replace('3','x'))

path2 = Path('C:\\Users\\hp\\Desktop\\Python_Projects\\my_project\\Fourth_Course\\random_study.ipynb')
contents2 = path2.read_text(encoding='utf-8')
print(contents2[0:100])
# Out:
# 3.141
# x.14159265x58979
#
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 1,
#    "id": "e6603305",
#    "metadata

# %%
from pathlib import Path
p = Path(r'C:\Users\hp\Desktop\Python_Projects\my_project\Test\test.txt')
contents = p.read_text().splitlines()
print(contents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[79], line 3
#       1 from pathlib import Path
#       2 p = Path(r'C:\Users\hp\Desktop\Python_Projects\my_project\Test\test.txt')
# ----> 3 contents = p.read_text().splitlines()
#       4 print(contents)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\pathlib\__init__.py:787, in Path.read_text(self, encoding, errors, newline)
#     784 # Call io.text_encoding() here to ensure any warning is raised at an
#     785 # appropriate stack level.
#     786 encoding = io.text_encoding(encoding)
# --> 787 with self.open(mode='r', encoding=encoding, errors=errors, newline=newline) as f:
#     788     return f.read()
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\pathlib\__init__.py:771, in Path.open(self, mode, buffering, encoding, errors, newline)
#     769 if "b" not in mode:
#     770     encoding = io.text_encoding(encoding)
# --> 771 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\hp\\Desktop\\Python_Projects\\my_project\\Test\\test.txt'

# %%
from pathlib import Path
import os

p = Path(r'C:\Users\hp\Desktop\Python_Projects\my_project\Test\test.txt') #绝对路径
contents = p.read_text().splitlines()
print(contents)


print(os.getcwd())
# Out:
# ['hhhhhhhhhhh', 'hhhhh mazizhuo']
# c:\Users\hp\Desktop\Python_Projects\my_project\Fourth_Course

# %%
import os
from pathlib import Path

target = r'C:\Users\hp\Desktop\Python_Projects\my_project\Other_Files\Other_Files.txt'
current_folder = r'C:\Users\hp\Desktop\Python_Projects\my_project\Fourth_Course\pathlib_study.ipynb'

current_dir = os.path.dirname(current_folder)
rel_path = os.path.relpath(target, current_dir)
print(rel_path)

p = Path(rel_path)
contents = p.read_text()
print(contents)
# Out:
# ..\Test\test.txt
# hhhhhhhhhhh
# hhhhh mazizhuo

# %%
from pathlib import Path
current_dir = Path.cwd()
target_dir = current_dir.parent / 'Test'
target_file = target_dir / 'test.txt'
contents = target_file.read_text()
print(contents)
# Out:
# hhhhhhhhhhh
# hhhhh mazizhuo

# %%
from pathlib import Path

# 获取当前 notebook 所在目录
current_dir = Path.cwd()

# 相对路径导航到目标文件
target = current_dir.parent / "Test" / "test.txt"

contents = target.read_text()
print(contents)
# Out:
# hhhhhhhhhhh
# hhhhh mazizhuo
